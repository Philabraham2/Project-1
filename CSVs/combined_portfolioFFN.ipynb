# %%
# Import necessary libraries and dependencies
import pandas as pd
from pathlib import Path
import ffn
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
 # Set the file paths for the CSVs using the Path class from the pathlib library
Combined_portfolio =  Path("combined_close_data_SP500_group_portfolio.csv")


# Read the daily closing prices of MSFT, set the `date` as a datetime index
combined_portfolio_df = pd.read_csv(Combined_portfolio, index_col=0, parse_dates=True, infer_datetime_format=True)

combined_portfolio_df.head()
# Out:
#                   SP500       ORCL     SQ       NVDA       BABA        PFE  \
# 2015-11-19  2081.239990  36.108597  13.07  30.458263  77.870003  27.049994
# 2015-11-20  2089.169922  36.404728  12.85  30.722525  79.949997  26.957846
# 2015-11-23  2086.590088  36.219639  12.12  30.262524  81.309998  26.245783
# 2015-11-24  2089.139893  36.515770  12.02  30.507206  80.860001  26.781923
# 2015-11-25  2088.870117  36.330700  11.90  30.468054  81.709999  27.535873
#
#                   NFLX        CRM          GD     AMT  ...    PSX     BLK  \
# 2015-11-19  120.220001  80.639999  130.626297   99.63  ...  92.38  359.09
# 2015-11-20  123.839996  80.989998  130.896194  100.49  ...  91.67  362.46
# 2015-11-23  125.029999  80.779999  130.077530   99.94  ...  92.17  363.25
# 2015-11-24  123.309998  80.389999  130.923172   99.26  ...  93.13  356.81
# 2015-11-25  124.160004  80.410004  130.608292   99.09  ...  92.77  360.62
#
# ...

# %%
perf = combined_portfolio_df.calc_stats()
# Out:
# C:\Users\evely\anaconda3\envs\pyvizenv2\lib\site-packages\ffn\core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)

# %%
perf
# Out:
# {'SP500': <ffn.core.PerformanceStats at 0x222576144c8>,
#  'ORCL': <ffn.core.PerformanceStats at 0x222575321c8>,
#  'SQ': <ffn.core.PerformanceStats at 0x2225753d1c8>,
#  'NVDA': <ffn.core.PerformanceStats at 0x2225756fbc8>,
#  'BABA': <ffn.core.PerformanceStats at 0x22257582188>,
#  'PFE': <ffn.core.PerformanceStats at 0x2225758d688>,
#  'NFLX': <ffn.core.PerformanceStats at 0x2225759b648>,
#  'CRM': <ffn.core.PerformanceStats at 0x222575a7588>,
#  'GD': <ffn.core.PerformanceStats at 0x222575b2c08>,
#  'AMT': <ffn.core.PerformanceStats at 0x222575bd488>,
#  'HD': <ffn.core.PerformanceStats at 0x222575cf388>,
#  'FB': <ffn.core.PerformanceStats at 0x22257657588>,
#  'MSFT': <ffn.core.PerformanceStats at 0x22257669388>,
#  'WMT': <ffn.core.PerformanceStats at 0x22257679508>,
#  'VZ': <ffn.core.PerformanceStats at 0x22257685248>,
#  'MCD': <ffn.core.PerformanceStats at 0x22257691408>,
#  'SBUX': <ffn.core.PerformanceStats at 0x2225769b288>,
# ...

# %%
#Histogram Plat for NVDA
perf['NVDA'].plot_histogram()
# Out:
# C:\Users\evely\anaconda3\envs\pyvizenv2\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
perf['SP500'].plot_histogram()
# Out:
# C:\Users\evely\anaconda3\envs\pyvizenv2\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
perf.plot(figsize=(60,30))

# %%
#Print performance stats for SP500
perf['SP500'].stats
# Out:
# start                    2015-11-19 00:00:00
# end                      2020-10-01 00:00:00
# rf                                         0
# total_return                        0.624416
# cagr                                0.104798
# max_drawdown                        -0.33925
# calmar                              0.308912
# mtd                               0.00529291
# three_month                        0.0850295
# six_month                           0.368468
# ytd                                0.0464346
# one_year                            0.149834
# three_year                          0.101655
# five_year                           0.104798
# ten_year                            0.104798
# incep                               0.104798
# daily_sharpe                        0.614674
# daily_sortino                       0.906786
# daily_mean                           0.11865
# daily_vol                           0.193029
# daily_skew                         -0.716517
# ...

# %%
#Assigning returns for portfolio
returns = combined_portfolio_df.to_log_returns().dropna()
returns.head()
# Out:
#                SP500      ORCL        SQ      NVDA      BABA       PFE  \
# 2015-11-20  0.003803  0.008168 -0.016976  0.008639  0.026361 -0.003412
# 2015-11-23 -0.001236 -0.005097 -0.058487 -0.015086  0.016868 -0.026769
# 2015-11-24  0.001221  0.008143 -0.008285  0.008053 -0.005550  0.020222
# 2015-11-25 -0.000129 -0.005081 -0.010034 -0.001284  0.010457  0.027762
# 2015-11-27  0.000593 -0.002040  0.012526  0.008317 -0.004047 -0.002437
#
#                 NFLX       CRM        GD       AMT  ...       PSX       BLK  \
# 2015-11-20  0.029667  0.004331  0.002064  0.008595  ... -0.007715  0.009341
# 2015-11-23  0.009563 -0.002596 -0.006274 -0.005488  ...  0.005440  0.002177
# 2015-11-24 -0.013852 -0.004840  0.006480 -0.006827  ...  0.010362 -0.017888
# 2015-11-25  0.006870  0.000249 -0.002408 -0.001714  ... -0.003873  0.010621
# 2015-11-27  0.010256 -0.005487  0.002614  0.005937  ... -0.000108 -0.006203
#
#                 TROW       JNJ       UNH       MMM       UPS       ACN  \
# ...

# %%
#Histograms for returns for Blk Porfolio and SP500
ax = returns.hist(figsize=(30,15))

# %%
#Different layout for Returns correlation
returns.corr().as_format('.2f')
# Out:
#        SP500   ORCL    SQ  NVDA  BABA    PFE   NFLX   CRM     GD    AMT  ...  \
# SP500   1.00   0.72  0.57  0.63  0.55   0.63   0.48  0.67   0.72   0.61  ...
# ORCL    0.72   1.00  0.39  0.45  0.41   0.49   0.37  0.53   0.49   0.45  ...
# SQ      0.57   0.39  1.00  0.51  0.44   0.27   0.41  0.54   0.36   0.32  ...
# NVDA    0.63   0.45  0.51  1.00  0.52   0.31   0.45  0.54   0.39   0.32  ...
# BABA    0.55   0.41  0.44  0.52  1.00   0.27   0.43  0.47   0.36   0.26  ...
# PFE     0.63   0.49  0.27  0.31  0.27   1.00   0.26  0.35   0.47   0.43  ...
# NFLX    0.48   0.37  0.41  0.45  0.43   0.26   1.00  0.52   0.28   0.23  ...
# CRM     0.67   0.53  0.54  0.54  0.47   0.35   0.52  1.00   0.40   0.40  ...
# GD      0.72   0.49  0.36  0.39  0.36   0.47   0.28  0.40   1.00   0.44  ...
# AMT     0.61   0.45  0.32  0.32  0.26   0.43   0.23  0.40   0.44   1.00  ...
# HD      0.79   0.54  0.46  0.51  0.37   0.48   0.36  0.54   0.57   0.50  ...
# ...

# %%
returns.plot_corr_heatmap(figsize=(30,15))
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\evely\\anaconda3\\envs\\pyvizenv2\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ax = combined_portfolio_df.rebase().plot(figsize=(30,10))
